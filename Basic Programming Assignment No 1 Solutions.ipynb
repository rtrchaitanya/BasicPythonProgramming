# %% [markdown]
# # 1.Write a Python program to print 'Hello Python' ?
#
# Answer :

# %%
print('Hello Python')
# Out:
# Hello Python

# %% [markdown]
# # 2.Write a Python program to do arithmetic operations addition and division ?
#
# Answer :

# %%
import operator

ops = { "+": operator.add, "-": operator.sub, "*":operator.mul, "/":operator.truediv } 

print('Select a Arithmetic Operation: \
        \n1.Addition(+)\
        \n2.Division(-)\
        \n2.Multiplication(*)\
        \n4.Division(/)\
        \n3.Stop(0)\n')
   

while True:
    operator = input('Enter a arithmetic operation -> ')
    if operator == '0':
        print("Program Stopped successfully")
        break
    elif operator not in ['+','-','*','/']:
        print("Please enter a valid operator")
    else:
        num_1 = int(input('\nEnter 1st Number: '))
        num_2 = int(input('Enter 2nd Number: '))
        print('{}{}{}={}\n'.format(num_1, operator, num_2, ops[operator](num_1,num_2)))
# Out:
# Select a Arithmetic Operation:
# 1.Addition(+)
# 2.Division(-)
# 2.Multiplication(*)
# 4.Division(/)
# 3.Stop(0)
#
# Enter a arithmetic operation -> +
#
# Enter 1st Number: 155
# Enter 2nd Number: 777
# 155+777=932
#
# Enter a arithmetic operation -> -
#
# Enter 1st Number: 489
# Enter 2nd Number: 269
# 489-269=220
#
# Enter a arithmetic operation -> *
#
# Enter 1st Number: 47
# Enter 2nd Number: 33
# 47*33=1551
#
# Enter a arithmetic operation -> /
#
# Enter 1st Number: 11111
# Enter 2nd Number: 6
# 11111/6=1851.8333333333333
#
# Enter a arithmetic operation -> 0
# Program Stopped successfully

# %% [markdown]
# # 3.Write a Python program to find the area of a triangle ?
#
# Answer :

# %%
height = int(input('Enter height of triangle: '))
base = int(input('Enter base of triangle: '))

def areaOfTriangle(height, base):
    print('\nArea of triangle ->', 0.5*height*base)

areaOfTriangle(height,base)
# Out:
# Enter height of triangle: 777
# Enter base of triangle: 555
#
# Area of triangle -> 215617.5

# %% [markdown]
# # 4.Write a Python program to swap two variables ?
#
# Answer :

# %%
num_1 = int(input("Enter First Number: "))
num_2 = int(input("Enter Second Number: "))

def swapNumbers(a,b):
    temp = a
    a = b
    b = temp
    return a,b

print('Before swapping -> ',num_1, num_2)
num_1, num_2 = swapNumbers(num_1, num_2)
print('After swapping -> ',num_1,num_2)
# Out:
# Enter First Number: 500
# Enter Second Number: 1000
# Before swapping ->  500 1000
# After swapping ->  1000 500

# %% [markdown]
# # 5.Write a Python program to generate a random number ?
#
# Answer :

# %%
from random import randint

def generateRandomNumber(start=0, end=100000):
    print('Random number -> ',randint(start,end))

# Generating random numbers without arguments    
generateRandomNumber()

# Generating random numbers with arguments    
generateRandomNumber(0,100)
# Out:
# Random number ->  96628
# Random number ->  3
